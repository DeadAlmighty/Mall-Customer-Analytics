# %%
# Import required libraries
import sys
import pandas as pd


# Add src folder to path so we can import our modules
sys.path.append('../src')

prediction_data_1 = pd.read_csv('../outputs/results/apriori_rules.csv')
a=prediction_data_1.head()

prediction_data_2 = pd.read_csv('../outputs/results/classification_results.csv')
b=prediction_data_2.head()


print(a)
print("---------------------------------------------------------------------------")
print(b)
# Out:
#                     antecedents                   consequents  \
# 0  frozenset({'High_Spending'})     frozenset({'Low_Income'})
# 1    frozenset({'High_Income'})   frozenset({'Low_Spending'})
# 2     frozenset({'Low_Income'})  frozenset({'High_Spending'})
# 3   frozenset({'Low_Spending'})     frozenset({'Low_Income'})
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.501018            0.751527  0.496945    0.991870  1.319805
# 1            0.248473            0.498982  0.244399    0.983607  1.971228
# 2            0.751527            0.501018  0.496945    0.661247  1.319805
# 3            0.498982            0.751527  0.254582    0.510204  0.678889
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.120416   30.562118       0.485614  0.657682   0.967280
# 1               1.0  0.120416   30.562118       0.655601  0.485830   0.967280
# ...
